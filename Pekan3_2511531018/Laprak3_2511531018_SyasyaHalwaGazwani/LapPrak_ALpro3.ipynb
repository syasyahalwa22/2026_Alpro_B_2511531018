# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMOGRAMAN**
#
# **“OPERATOR PADA PYTHON”**
#
# **Disusun Oleh :**
#
# **Syasya Halwa Gazwani**
#
# **2511531018**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Alvero**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Algortima dan Pemrograman yang telah dilaksanakan sebagai pertemuan ke-3 untuk mata kuliah Praktikum Algortima dan Pemrograman. Praktikum ini berfokus pada pembahasan Operator pada Python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep Operator pada Python pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Python merupakan salah satu bahasa pemrograman yang memiliki berbagai jenis operator untuk melakukan proses perhitungan, perbandingan, pemberian nilai, hingga pengolahan data. Pemahaman terhadap operator seperti aritmatika, perbandingan, logika, assignment, keanggotaan, identitas, dan bitwise penting untuk membuat program yang dapat bekerja sesuai dengan kondisi yang diberikan. Oleh karena itu, praktikum ini dilakukan untuk mempelajari penggunaan berbagai operator dasar pada Python melalui program sederhana.
#
# ## 1.2 Tujuan
# 1. Memahami fungsi dan cara penggunaan berbagai operator pada Python.
# 2. Mengetahui jenis-jenis operator dalam Python.
# 3. Memahami hasil dari setiap operasi yang dilakukan oleh program.
#
# ## 1.3 Manfaat
# 1. Menambah pemahaman mengenai dasar-dasar pemrograman Python.
# 2. Melatih kemampuan dalam menggunakan berbagai operator Python.
# 3. Membantu dalam membuat logika dan proses perhitungan pada program.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Python merupakan bahasa pemrograman tingkat tinggi yang memiliki sintaks sederhana dan mudah dipahami. Dalam pemrograman, operator digunakan untuk melakukan operasi terhadap nilai atau variabel. Operator pada Python terdiri dari beberapa jenis, seperti operator aritmatika, perbandingan, logika, assignment, keanggotaan, identitas, dan bitwise.
# 1. Operator aritmatika digunakan untuk melakukan operasi matematika, seperti penjumlahan (+), pengurangan (-), perkalian (*), pembagian (/), perpangkatan (**), sisa bagi (%), dan pembagian bulat (//). Operator ini digunakan dalam berbagai proses perhitungan di dalam program.
#
# 2. Operator perbandingan digunakan untuk membandingkan dua nilai. Operator yang digunakan antara lain lebih besar (>), lebih kecil (<), lebih besar atau sama dengan (>=), lebih kecil atau sama dengan (<=), sama dengan (==), dan tidak sama dengan (!=). Hasil dari operasi perbandingan berupa nilai boolean, yaitu True atau False.
#
# 3. Operator logika digunakan untuk menggabungkan atau membalik suatu kondisi. Operator yang umum digunakan adalah and, or, dan not. Operator and menghasilkan True jika kedua kondisi benar, or menghasilkan True jika salah satu kondisi benar, sedangkan not digunakan untuk membalik nilai boolean.
#
# 4. Operator assignment digunakan untuk memberikan nilai atau memperbarui nilai pada variabel. Operator dasarnya adalah =, sedangkan operator gabungannya meliputi +=, -=, *=, /=, //=, %=, dan **=. Operator tersebut memungkinkan proses pemberian nilai dan perhitungan dilakukan secara lebih sederhana.
#
# 5. Operator keanggotaan digunakan untuk memeriksa keberadaan suatu nilai di dalam suatu kumpulan data, seperti list. Operator in digunakan untuk mengecek apakah suatu nilai terdapat di dalam kumpulan data, sedangkan not in digunakan untuk mengecek apakah nilai tersebut tidak terdapat di dalamnya.
#
# 6. Operator identitas digunakan untuk memeriksa apakah dua variabel merujuk pada objek yang sama. Operator is digunakan ketika dua variabel merujuk pada objek yang sama, sedangkan is not digunakan untuk mengecek apakah keduanya merupakan objek yang berbeda.
#
# 7. Operator bitwise digunakan untuk melakukan operasi pada representasi biner suatu bilangan. Operator yang digunakan meliputi AND (&), OR (|), XOR (^), NOT (~), geser kiri (<<), dan geser kanan (>>).

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "aritmatika_2511531018"
# Program aritmatika pada Python merupakan program sederhana yang digunakan untuk melakukan berbagai operasi perhitungan matematika. Pada program ini, terdapat beberapa operator aritmatika seperti + untuk penjumlahan, - untuk pengurangan, * untuk perkalian, / untuk pembagian, ** untuk perpangkatan, % untuk mencari sisa hasil bagi, dan // untuk pembagian bulat. Nilai yang akan dihitung disimpan terlebih dahulu ke dalam variabel, kemudian dilakukan operasi menggunakan operator yang sesuai.

# %%
angka1_1018 = int(input("Input angka-1: "))
angka2_1018 = int(input("Input angka-2: "))

#Penjumlahan
hasil_1018 = angka1_1018 + angka2_1018
print("\nOperator Penjumlahan")
print("Hasil =", hasil_1018)

#Pengurangan
hasil_1018 = angka1_1018 - angka2_1018
print("\nOperator Pengurangan")
print("Hasil =", hasil_1018)

#Perkalian
hasil_1018 = angka1_1018 * angka2_1018
print("\nOperator Perkalian")           
print("Hasil =", hasil_1018)

#Pembagian, pembagian bulat, dan sisa bagi
if angka2_1018 != 0:
    hasil_1018 = angka1_1018 / angka2_1018
    print("\nOperator Pembagian")
    print("Hasil =", hasil_1018) 

    hasil_1018 = angka1_1018 // angka2_1018
    print("\nOperator Pembagian Bulat")
    print("Hasil =", hasil_1018)

    hasil_1018 = angka1_1018 % angka2_1018
    print("\nOperator Sisa Bagi")
    print("Hasil =", hasil_1018)
else:
    print("Angka kedua tidak boleh bernilai 0.")

#Pangkat
hasil_1018 = angka1_1018 ** angka2_1018
print("\nOperator Pangkat")
print("Hasil =", hasil_1018)
# Out:
# Operator Penjumlahan
# Hasil = 16
#
# Operator Pengurangan
# Hasil = 8
#
# Operator Perkalian
# Hasil = 48
#
# Operator Pembagian
# Hasil = 3.0
#
# Operator Pembagian Bulat
# Hasil = 3
#
# Operator Sisa Bagi
# Hasil = 0
#
# Operator Pangkat
# Hasil = 20736

# %% [markdown]
# **Penjelasan :**
# 1. Berfungsi sebagai tempat dimna user dapat menginputkan nilai pada program. User disuruh untuk menginput nilai pada angka 1 dan nilai pada angka 2. Contohnya disini user menginput angka 1 = 12 dan angka 2 = 4.
# 2. Operator penjumlahan berfungsi untuk menjumlahkan nilai angka 1 dan angka 2. Pada output akan menghasilkan hasil dari penjumlahan angka 1 dan angka 2.
# 3. Operator pengurangan berfungsi untuk menjalankan program pengurangan dari angka 1 dan angka 2. Pada output Operator Pengurangan akan menghasilkan hasil dari pengurangan angka 1 dan angka 2.
# 4. Operator perkalian berfungsi untuk menjalankan program perkalian dari angka 1 dan angka 2. Pada output Operator Perkalian akan menghasilkan hasil dari perkalian angka 1 dan angka 2.
# 5. Operator pembagian berfungsi untuk menjalankan program pembagian pada angka 1 dan angka 2. Pada output akan menghasilkan hasil pembagian dari angka 1 dan angka 2.
# 6. Pada Operator Pembagian Bulat berfungsi untuk menjalankan program pembagian pada angka 1 dan angka 2. Pada output akan menghasilkan hasil dari pembagian angka 1 dan angka 2, namun hanya mengambil nilai bulatnya saja, misalnya 3,333 menjadi 3. Maka, 3 adalah hasil dari pembagian bulatnya.
# 7. Pada Operator Sisa Bagi berfungsi mengambil sisa pembagian pada angka 1 dan angka 2. Namun, apabila user menginput angka 0, program tidak bisa menghasilkan hasil.
# 8. Pada Operator Pangkat, angka 1 yang telah di input dipangkatkan dengan angka 2, maka akan menghasilkan angka 1 dengan pangkat angka 2.

# %% [markdown]
# ### 2.2.2 Program "perbandingan_2511531018"
#
# Program perbandingan pada Python digunakan untuk membandingkan dua buah nilai atau lebih. Operator perbandingan akan menghasilkan nilai True jika kondisi yang dibandingkan benar dan False jika kondisi tersebut salah. Beberapa operator yang digunakan yaitu == untuk membandingkan apakah dua nilai sama, != untuk membandingkan apakah dua nilai berbeda, > untuk lebih besar, < untuk lebih kecil, >= untuk lebih besar atau sama dengan, serta <= untuk lebih kecil atau sama dengan. Program ini dapat digunakan untuk mengetahui hubungan antara dua nilai berdasarkan kondisi yang diberikan.

# %%
angka1_1018 = int(input("Input angka-1: "))
angka2_1018 = int(input("Input angka-2: "))

#Lebih besar dari
hasil_1018 = angka1_1018 > angka2_1018
print("\nOperator lebih besar dari")
print("angka1_1018 > angka2_1018 =", hasil_1018)

#Lebih kecil dari
hasil_1018 = angka1_1018 < angka2_1018
print("\nOperator lebih kecil dari")
print("angka1_1018 < angka2_1018 =", hasil_1018)

#Lebih besar dari atau sama dengan
hasil_1018 = angka1_1018 >= angka2_1018
print("\nOperator lebih besar dari atau sama dengan")
print("angka1_1018 >= angka2_1018 =", hasil_1018)

#Lebih kecil atau sama dengan
hasil_1018 = angka1_1018 <= angka2_1018
print("\nOperator lebih kecil dari atau sama dengan")
print("angka1_1018 <= angka2_1018 =", hasil_1018)

#Sama dengan
hasil_1018 = angka1_1018 == angka2_1018
print("\nOperator sama dengan")
print("angka1_1018 == angka2_1018 =", hasil_1018)

#Tidak sama dengan
hasil_1018 = angka1_1018 != angka2_1018
print("\nOperator tidak sama dengan")
print("angka1_1018 != angka2_1018 =", hasil_1018)

#Tambahan: perbandingan berantai dalam Python
hasil_1018 = 0 < angka1_1018 < 100 
print("\nPerbandingan berantai")
print("0 < angka1_1018 < 100 =", hasil_1018)

hasil_1018 = 0 < angka2_1018 < 100
print("0 < angka2_1018 < 100 =", hasil_1018)
# Out:
# Operator lebih besar dari
# angka1_1018 > angka2_1018 = True
#
# Operator lebih kecil dari
# angka1_1018 < angka2_1018 = False
#
# Operator lebih besar dari atau sama dengan
# angka1_1018 >= angka2_1018 = True
#
# Operator lebih kecil dari atau sama dengan
# angka1_1018 <= angka2_1018 = False
#
# Operator sama dengan
# angka1_1018 == angka2_1018 = False
#
# Operator tidak sama dengan
# angka1_1018 != angka2_1018 = True
#
# Perbandingan berantai
# 0 < angka1_1018 < 100 = True
# 0 < angka2_1018 < 100 = True

# %% [markdown]
# **Penjelasan :**
# 1. angka1_1018 = int(input("Input angka-1: ")) dan angka2_1018 = int(input("Input angka-2: ")) digunakan untuk user meginput angka 1 dan 2, sebagai contoh user menginput angka 1 = 12 dan angka 2 = 4.
# 2. hasil_1018 = angka1_1018 > angka2_1018 digunakan untuk memeriksa apakah angka 1 lebih besar dari angka 2. jika angka 1 lebih besar, maka akan menghasilkan true.
# 3. hasil_1018 = angka1_1018 < angka2_1018 digunakan untuk memeriksa apakah angka 1 lebih kecil dari angka 2. Jia angka 1 lebih kecil, maka akan menghasilkan true.
# 4. hasil_1018 = angka1_1018 >= angka2_1018 digunakan untuk memeriksa apakah angka 1 lebih besar atau sama dengan angka 2.
# 5. hasil_1018 = angka1_1018 <= angka2_1018 digunakan untuk memeriksa apakah angka 1 lebih kecil atau sama dengan angka 2.
# 6. hasil_1018 = angka1_1018 == angka2_1018 digunakan untuk memeriksa apakah angka 1 sama dengan angka 2.
# 7. hasil_1018 = angka1_1018 != angka2_1018 digunakan untuk memeriksa apakah kedua angka memiliki nilai yang berbeda.
# 8. hasil_1018 = 0 < angka1_1018 < 100 digunakan untuk memeriksa apakah angka 1 berada di antara 0 dan 100. Kondisi ini bernilai True jika angka 1 lebih besar dari 0 dan lebih kecil dari 100.
# 9. hasil_1018 = 0 < angka2_1018 < 100 digunakan untuk memeriksa apakah angka 2 berada di antara 0 dan 100. Kondisi ini bernilai True jika angka 2 lebih besar dari 0 dan lebih kecil dari 100.

# %% [markdown]
# ### 2.2.3 Program "logika_2511531018"
# Program logika pada Python digunakan untuk menggabungkan atau membandingkan beberapa kondisi dalam suatu program. Operator logika yang digunakan yaitu and, or, dan not. Operator and menghasilkan True apabila semua kondisi bernilai benar, sedangkan or menghasilkan True apabila salah satu kondisi bernilai benar. Sementara itu, not digunakan untuk membalik nilai logika, sehingga kondisi True menjadi False dan sebaliknya. Operator logika biasanya digunakan ketika program memiliki lebih dari satu kondisi yang harus diperiksa.

# %%
#Memasukkan nilai boolean
#Input tidak peka terhadap huruf besar dan kecil
a1_1018 = input("Input nilai boolean-1 (true/falses): ").strip().lower() == "true" 
a2_1018 = input("Input nilai boolean-2 (true/falses): ").strip().lower() == "true"

print("\nA1 =", a1_1018)
print("\nA2 =", a2_1018)

#Konjungsi: bernilai True jika keduanya True
hasil_1018 = a1_1018 and a2_1018
print("\nKonjungsi (AND)")
print("A1 and A2 =", hasil_1018)

#Disjungsi: bernilai True jika salah satunya True
hasil_1018 = a1_1018 or a2_1018
print("\nDisjungsi (OR)")
print("A1 or A2 =", hasil_1018)

#Negasi A1: membalik nilai A1
hasil_1018 = not a1_1018
print("\nNegasi A1 (NOT)")  
print("not A1 =", hasil_1018)

#Negasi A2: membalik nilai A2
hasil_1018 = not a2_1018
print("\nNegasi A2 (NOT)")
print("not A2 =", hasil_1018)

#XOR: bernilai True jika kedua nilai berbeda
hasil_1018 = a1_1018 != a2_1018
print("\nDisjungsi Eksklusif (XOR)")
print("A1 xor A2 =", hasil_1018)
# Out:
# A1 = True
#
# A2 = False
#
# Konjungsi (AND)
# A1 and A2 = False
#
# Disjungsi (OR)
# A1 or A2 = True
#
# Negasi A1 (NOT)
# not A1 = False
#
# Negasi A2 (NOT)
# not A2 = True
#
# Disjungsi Eksklusif (XOR)
# A1 xor A2 = True

# %% [markdown]
# **Penjelasan :**
# 1. a1_1018 = input("Input nilai boolean-1 (true/falses): ").strip().lower() == "true" dan a2_1018 = input("Input nilai boolean-2 (true/falses): ").strip().lower() == "true" digunakan untuk menerima nilai boolean pertama dan kedua. strip() untuk menghapus spasi, dan lower() yang dapat membuat program dapat menerima input dalam bentuk huruf besar maupun kecil.
# 2. print("\nA1 =", a1_1018) dan print("\nA2 =", a2_1018) untuk menampilkan nilai yang telah dimasukkan.
# 3. hasil_1018 = a1_1018 and a2_1018 merupakan operator AND, hasilnya True jika kedua nilai bernilai True.
# 4. hasil_1018 = a1_1018 or a2_1018 merupakan operator OR, Hasilnya True jika salah satu atau kedua nilai bernilai True.
# 5. hasil_1018 = not a1_1018 merupakan operator NOT, digunakan untuk membalik nilai a1_1018. Jika nilainya True, hasilnya menjadi False, begitu juga sebaliknya.
# 6. hasil_1018 = not a2_1018 merupakan operator NOT, digunakan untuk membalik nilai a2_1018. Jika nilainya True, hasilnya menjadi False, begitu juga sebaliknya.
# 7. hasil_1018 = a1_1018 != a2_1018 merupakan operator XOR, hasilnya True jika kedua nilai berbeda, dan False jika keduanya sama.

# %% [markdown]
# ### 2.2.4 Program "lainnya_2511531018"
# Program lainnya_2511531018 merupakan program yang mempelajari operator keanggotaan dan operator identitas pada Python. Operator keanggotaan in dan not in digunakan untuk mengecek apakah suatu nilai terdapat dalam sebuah list. Sedangkan operator identitas is dan is not digunakan untuk mengecek apakah dua variabel merujuk pada objek yang sama. Program ini juga menunjukkan perbedaan antara is dan ==, yaitu is membandingkan identitas objek, sedangkan == membandingkan nilai atau isi objek.

# %%
print("===================================")
print("1. OPERATOR KEANGGOTAAN")
print("===================================")

#Input beberapa data yang dipisahkan dengan koma
input_data_1018 = input("Masukkan beberapa angka, pisahkan dengan koma: ")

#Mengubah input menjadi list integer
data_1018 = [int(angka.strip()) for angka in input_data_1018.split(",")]

nilai_dicari_1018 = int(input("Masukkan angka yang ingin dicari: "))

#Operator in
hasil_1018 = nilai_dicari_1018 in data_1018
print("\nOperator keanggotaan IN")
print(nilai_dicari_1018, "in", data_1018, "=", hasil_1018)

#Operator not in
hasil_1018 = nilai_dicari_1018 not in data_1018
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari_1018, "not in", data_1018, "=", hasil_1018)


print("\n===================================")
print("2. OPERATOR IDENTITAS")
print("===================================")

#objek1 menggunakan list dari input pengguna
objek1_1018 = data_1018

#objek2 merujuk pada objek yang sama dengan objek1
objek2_1018 = objek1_1018

#objek3 memiliki isi sama, tetapi merupakan objek baru
objek3_1018 = data_1018.copy()

print("objek1 =", objek1_1018)
print("objek2 =", objek2_1018)
print("objek3 =", objek3_1018)

#Operator is
hasil_1018 = objek1_1018 is objek2_1018
print("\nOperator identitas IS")    
print("objek1 is objek2 =", hasil_1018)

#Operator is not
hasil_1018 = objek1_1018 is not objek3_1018
print("\nOperator identitas IS NOT")
print("objek1 is not objek3 =", hasil_1018)

#Membandingkan identitas dan nilai
print("\nPerbandingan identitas dan nilai")
print("objek1 is objek3 =", objek1_1018 is objek3_1018)
print("objek1 == objek3 =", objek1_1018 == objek3_1018)
# Out:
# ...
# 1. OPERATOR KEANGGOTAAN
# ...
#
# Operator keanggotaan IN
# 4 in [2, 4, 6, 8, 9] = True
#
# Operator keanggotaan NOT IN
# 4 not in [2, 4, 6, 8, 9] = False
#
# ...
# 2. OPERATOR IDENTITAS
# ...
# objek1 = [2, 4, 6, 8, 9]
# objek2 = [2, 4, 6, 8, 9]
# objek3 = [2, 4, 6, 8, 9]
#
# Operator identitas IS
# objek1 is objek2 = True
#
# Operator identitas IS NOT
# objek1 is not objek3 = True
#
# Perbandingan identitas dan nilai
# objek1 is objek3 = False
# objek1 == objek3 = True

# %% [markdown]
# **Penjelasan :**
# 1. input_data_1018 = input("Masukkan beberapa angka, pisahkan dengan koma: ") digunakan untuk menerima beberapa angka dari pengguna dalam bentuk input teks yang dipisahkan dengan koma.
# 2. data_1018 = [int(angka.strip()) for angka in input_data_1018.split(",")] digunakan untuk memisahkan input berdasarkan koma, menghapus spasi dengan strip(), lalu mengubah setiap data menjadi integer dan menyimpannya dalam bentuk list.
# 3. nilai_dicari_1018 = int(input("Masukkan angka yang ingin dicari: ")) digunakan untuk menerima angka yang ingin dicari dari dalam list.
# 4. hasil_1018 = nilai_dicari_1018 in data_1018 digunakan untuk mengecek apakah angka yang dicari terdapat di dalam list menggunakan operator in. Hasilnya berupa True atau False.
# 5. print(nilai_dicari_1018, "in", data_1018, "=", hasil_1018) digunakan untuk menampilkan hasil pengecekan operator in.
# 6. hasil_1018 = nilai_dicari_1018 not in data_1018 digunakan untuk mengecek apakah angka yang dicari tidak terdapat di dalam list menggunakan operator not in.
# 7. print(nilai_dicari_1018, "not in", data_1018, "=", hasil_1018) digunakan untuk menampilkan hasil pengecekan operator not in.
# 8. objek1_1018 = data_1018 digunakan untuk membuat objek1 yang merujuk pada list data_1018.  objek2_1018 = objek1_1018 digunakan untuk membuat objek2 yang merujuk pada objek yang sama dengan objek1. objek3_1018 = data_1018.copy() digunakan untuk membuat objek list baru yang memiliki isi sama dengan data_1018, tetapi identitas objeknya berbeda.
# 9. print("objek1 =", objek1_1018), print("objek2 =", objek2_1018), dan print("objek3 =", objek3_1018) digunakan untuk menampilkan isi dari objek pertama, kedua, dan ketiga.
# 10. hasil_1018 = objek1_1018 is objek2_1018 digunakan untuk mengecek apakah objek1 dan objek2 merupakan objek yang sama menggunakan operator is. Hasilnya True karena keduanya merujuk pada objek yang sama.
# 11. print("objek1 is objek2 =", hasil_1018) digunakan untuk menampilkan hasil pengecekan identitas antara objek1 dan objek2.
# 12. hasil_1018 = objek1_1018 is not objek3_1018 digunakan untuk mengecek apakah objek1 dan objek3 merupakan objek yang berbeda menggunakan operator is not.
# 13. print("objek1 is not objek3 =", hasil_1018) digunakan untuk menampilkan hasil pengecekan identitas kedua objek tersebut.
# 14. print("objek1 is objek3 =", objek1_1018 is objek3_1018) digunakan untuk mengecek secara langsung apakah objek1 dan objek3 memiliki identitas objek yang sama. Hasilnya False.
# 15. print("objek1 == objek3 =", objek1_1018 == objek3_1018) digunakan untuk membandingkan isi objek1 dan objek3. Hasilnya True jika isi keduanya sama, meskipun objeknya berbeda.

# %% [markdown]
# ### 2.2.5 Program "assignment_2511531018"
# Program assignment pada Python digunakan untuk memberikan atau mengubah nilai yang tersimpan di dalam sebuah variabel. Dengan menggunakan operator assignment, penulisan program dapat menjadi lebih singkat dan memudahkan proses perubahan nilai pada variabel.

# %%
angka1_1018 = int(input("Input angka-1: "))
angka2_1018 = int(input("Input angka-2: "))

print("\nNilai awal angka1 =", angka1_1018)
print("Nilai angka2 =", angka2_1018)

# Assignment biasa
hasil_1018 = angka1_1018
print("\nAssigntment biasa (=)")
print("Hasil =", hasil_1018)

#Assignment penambahan
hasil_1018 = angka1_1018
hasil_1018 += angka2_1018
print("\nAssignment penambahan (+=)")
print("Hasil =", hasil_1018)

#Assignment pengurangan
hasil_1018 = angka1_1018
hasil_1018 -= angka2_1018
print("\nAssignment pengurangan (-=)")
print("Hasil =", hasil_1018)

#Assignment perkalian
hasil_1018 = angka1_1018
hasil_1018 *= angka2_1018
print("\nAssignment perkalian (*=)")
print("Hasil =", hasil_1018)

#Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_1018 != 0:
    hasil_1018 = angka1_1018
    hasil_1018 /= angka2_1018
    print("\nAssignment pembagian (/=)")
    print("Hasil =", hasil_1018)
    #Operator tambahan
    hasil_1018 = angka1_1018
    hasil_1018 //= angka2_1018
    print("\nAssignment pembagian bulat (//=)")
    print("Hasil =", hasil_1018)
    hasil_1018 = angka1_1018
    hasil_1018 %= angka2_1018
    print("\nAssignment sisa bagi (%=)")
    print("Hasil =", hasil_1018)
else:
    print("\nPembagian tidak dapat dilakukan.")
    print("Angka kedua tidak boleh bernilai 0.")

#Operator tambahan: assignment perpangkatan
hasil_1018 = angka1_1018
hasil_1018 **= angka2_1018
print("\nAssignment perpangkatan (**=)")
print("Hasil =", hasil_1018)
# Out:
# Nilai awal angka1 = 12
# Nilai angka2 = 4
#
# Assigntment biasa (=)
# Hasil = 12
#
# Assignment penambahan (+=)
# Hasil = 16
#
# Assignment pengurangan (-=)
# Hasil = 8
#
# Assignment perkalian (*=)
# Hasil = 48
#
# Assignment pembagian (/=)
# Hasil = 3.0
#
# Assignment pembagian bulat (//=)
# Hasil = 3
#
# Assignment sisa bagi (%=)
# Hasil = 0
#
# Assignment perpangkatan (**=)
# Hasil = 20736

# %% [markdown]
# **Penjelasan :**
# 1. angka1_1018 = int(input("Input angka-1: ")) dan angka2_1018 = int(input("Input angka-2: ")) digunakan untuk meminta pengguna memasukkan angka 1 dan angka 2, lalu mengubahnya menjadi tipe data integer.
# 2. print("\nNilai awal angka1 =", angka1_1018) dan print("Nilai angka2 =", angka2_1018) digunakan untuk meminta pengguna memasukkan angka kedua dan mengubahnya menjadi integer, menampilkan nilai awal dari angka pertama, dan menampilkan nilai dari angka kedua.
# 3. hasil_1018 = angka1_1018 merupakan assignment biasa (=) yang digunakan untuk memberikan nilai angka1_1018 ke variabel hasil_1018.
# 4. hasil_1018 += angka2_1018, hasil_1018 -= angka2_1018, dan hasil_1018 *= angka2_1018 merupakan assignment penambahan (+=), pengurangan (-=), dan perkalian yang menambahkan, mengurangi, dan mengalikan nilai angka2_1018 ke hasil_1018.
# 5. if angka2_1018 != 0: digunakan untuk mengecek apakah angka kedua tidak sama dengan 0.
# 6. hasil_1018 /= angka2_1018 merupakan assignment pembagian (/=) yang membagi nilai hasil_1018 dengan angka2_1018.
# 7. hasil_1018 //= angka2_1018 merupakan assignment pembagian bulat (//=) yang membagi nilai dan mengambil hasil pembagian dalam bentuk bilangan bulat.
# 8.  hasil_1018 %= angka2_1018 merupakan assignment sisa bagi (%=) yang menghasilkan sisa dari pembagian hasil_1018 dengan angka2_1018.
# 9. else: dijalankan apabila kondisi if tidak terpenuhi, yaitu ketika angka kedua bernilai 0.
# 10. hasil_1018 **= angka2_1018 merupakan assignment perpangkatan yang menaikkan nilai hasil_1018 dengan pangkat angka2_1018.
# 11. print("Hasil =", hasil_1018) digunakan untuk menampilkan hasil dari setiap operasi assignment yang dilakukan.

# %% [markdown]
# ### 2.2.6 Program "bitwise_2511531018"
# Program bitwise pada Python digunakan untuk melakukan operasi terhadap data dalam bentuk bit biner, yaitu angka 0 dan 1. Operator bitwise yang umum digunakan antara lain & (AND), | (OR), ^ (XOR), ~ (NOT), << (left shift), dan >> (right shift).

# %%
print("\n===================================")
print("3. OPERATOR BITWISE")
print("===================================")

angka1_1018 = int(input("Masukkan angka bitwise-1: "))
angka2_1018 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1_1018 =", angka1_1018, "| biner =", bin(angka1_1018))
print("angka2_1018 =", angka2_1018, "| biner =", bin(angka2_1018))

#Bitwise AND
hasil_1018 = angka1_1018 & angka2_1018
print("\nBitwise AND (&)")
print(angka1_1018, "&", angka2_1018, "=", hasil_1018,)
print("Biner hasil =", bin(hasil_1018))
print("Biner hasil (8 bit) =", format(hasil_1018, '08b'))

#Bitwise OR
hasil_1018 = angka1_1018 | angka2_1018
print("\nBitwise OR (|)")
print(angka1_1018, "|", angka2_1018, "=", hasil_1018)
print("Biner hasil =", bin(hasil_1018))
print("Biner hasil (8 bit) =", format(hasil_1018, '08b'))

#Bitwise XOR
hasil_1018 = angka1_1018 ^ angka2_1018
print("\nBitwise XOR (^)")
print(angka1_1018, "^", angka2_1018, "=", hasil_1018)
print("Biner hasil =", bin(hasil_1018))
print("Biner hasil (8 bit) =", format(hasil_1018, '08b'))

#Bitwise NOT
hasil_1018 = ~angka1_1018
print("\nBitwise NOT (~)")
print("~", angka1_1018, "=", hasil_1018)
print("Biner hasil =", bin(hasil_1018))
print("Biner hasil (8 bit) =", format(hasil_1018, '08b'))

#Bitwise geser kiri
jumlah_geser_1018 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_1018 = angka1_1018 << jumlah_geser_1018
print("\nBitwise geser kiri (<<)")
print(angka1_1018, "<<", jumlah_geser_1018, "=", hasil_1018)
print("Biner hasil =", bin(hasil_1018))
print("Biner hasil (8 bit) =", format(hasil_1018, '08b'))

#Bitwise geser kanan
hasil_1018 = angka1_1018 >> jumlah_geser_1018
print("\nBitwise geser kanan (>>)")
print(angka1_1018, ">>", jumlah_geser_1018, "=", hasil_1018)
print("Biner hasil =", bin(hasil_1018))
print("Biner hasil (8 bit) =", format(hasil_1018, '08b'))
# Out:
# ...
# 3. OPERATOR BITWISE
# ...
#
# Angka dalam bentuk desimal dan biner
# angka1_1018 = 12 | biner = 0b1100
# angka2_1018 = 4 | biner = 0b100
#
# Bitwise AND (&)
# 12 & 4 = 4
# Biner hasil = 0b100
# Biner hasil (8 bit) = 00000100
#
# Bitwise OR (|)
# 12 | 4 = 12
# Biner hasil = 0b1100
# Biner hasil (8 bit) = 00001100
#
# Bitwise XOR (^)
# 12 ^ 4 = 8
# Biner hasil = 0b1000
# Biner hasil (8 bit) = 00001000
#
# Bitwise NOT (~)
# ~ 12 = -13
# Biner hasil = -0b1101
# Biner hasil (8 bit) = -0001101
#
# Bitwise geser kiri (<<)
# 12 << 2 = 48
# Biner hasil = 0b110000
# Biner hasil (8 bit) = 00110000
#
# Bitwise geser kanan (>>)
# 12 >> 2 = 3
# Biner hasil = 0b11
# Biner hasil (8 bit) = 00000011

# %% [markdown]
# **Penjelasan :**
# 1. angka1_1018 = int(input("Masukkan angka bitwise-1: ")) digunakan untuk menerima angka pertama dari pengguna dan mengubahnya menjadi tipe data integer.
# 2. angka2_1018 = int(input("Masukkan angka bitwise-2: ")) digunakan untuk menerima angka kedua dari pengguna dan mengubahnya menjadi integer.
# 3. print("angka1_1018 =", angka1_1018, "| biner =", bin(angka1_1018)) digunakan untuk menampilkan angka pertama dalam bentuk desimal dan biner. Fungsi bin() digunakan untuk mengubah angka menjadi bentuk biner.
# 4. print("angka2_1018 =", angka2_1018, "| biner =", bin(angka2_1018)) digunakan untuk menampilkan angka kedua dalam bentuk desimal dan biner.
# 5. hasil_1018 = angka1_1018 & angka2_1018 digunakan untuk melakukan operasi Bitwise AND (&), yaitu membandingkan setiap bit dari kedua angka dan menghasilkan 1 jika kedua bit bernilai 1.
# 6. print(angka1_1018, "&", angka2_1018, "=", hasil_1018) digunakan untuk menampilkan hasil operasi Bitwise AND dalam bentuk desimal.
# 7. print("Biner hasil =", bin(hasil_1018)) digunakan untuk menampilkan hasil Bitwise AND dalam bentuk biner.
# 8. print("Biner hasil (8 bit) =", format(hasil_1018, '08b')) digunakan untuk menampilkan hasil biner dengan format 8 bit, sehingga angka biner yang ditampilkan memiliki panjang 8 digit.
# 9. hasil_1018 = angka1_1018 | angka2_1018 digunakan untuk melakukan operasi Bitwise OR (|), yaitu menghasilkan 1 jika salah satu atau kedua bit bernilai 1.
# 10. hasil_1018 = angka1_1018 ^ angka2_1018 digunakan untuk melakukan operasi Bitwise XOR (^), yaitu menghasilkan 1 jika kedua bit memiliki nilai yang berbeda.
# 11. hasil_1018 = ~angka1_1018 digunakan untuk melakukan operasi Bitwise NOT (~), yaitu membalik setiap bit dari angka pertama.
# 12. jumlah_geser_1018 = int(input("\nMasukkan jumlah pergeseran bit: ")) digunakan untuk meminta pengguna memasukkan jumlah posisi bit yang akan digeser.
# 14. hasil_1018 = angka1_1018 << jumlah_geser_1018 digunakan untuk melakukan pergeseran bit ke kiri (<<) sebanyak jumlah posisi yang dimasukkan. Pergeseran ini umumnya membuat nilai bilangan menjadi lebih besar.
# 15. print(angka1_1018, "<<", jumlah_geser_1018, "=", hasil_1018) digunakan untuk menampilkan hasil operasi pergeseran bit ke kiri.
# 16. hasil_1018 = angka1_1018 >> jumlah_geser_1018 digunakan untuk melakukan pergeseran bit ke kanan (>>) sebanyak jumlah posisi yang dimasukkan. Untuk bilangan positif, pergeseran ini umumnya membuat nilai menjadi lebih kecil.
# 17. print(angka1_1018, ">>", jumlah_geser_1018, "=", hasil_1018) digunakan untuk menampilkan hasil operasi pergeseran bit ke kanan.
# 18. bin(hasil_1018) digunakan untuk mengubah hasil operasi bitwise menjadi bentuk biner, sedangkan format(hasil_1018, '08b') digunakan untuk menampilkan hasil biner dalam format 8 bit.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="images/SoalAlproPekan3.1 .png" width="500"><br>
# </div>
#
# <div align="center">
# <img src="images/SoalAlproPekan3.2.png" width="500"><br>
# </div>
#
# <div align="center">
# <img src="images/SoalAlproPekan3.3.png" width="500"><br>
# </div>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "tugas3_2511531018"

# %%
print("==========================================")
print("       SISTEM TRANSAKSI TOKO")
print("==========================================")

# ==============================
# INPUT DATA PELANGGAN
# ==============================

nama_1018 = input("Masukkan Nama Pelanggan : ")
status_1018 = input("Masukkan Status Pelanggan (member/nonmember) : ").lower()
belanja_1018 = float(input("Masukkan Total Harga Belanja : Rp"))
jumlah_1018 = int(input("Masukkan Jumlah Barang : "))
kode_promo_1018 = input("Masukkan Kode Promo : ").upper()


# OPERATOR PERBANDINGAN
syarat_belanja_1018 = belanja_1018 >= 200000
syarat_jumlah_1018 = jumlah_1018 >= 3
status_anggota_1018 = status_1018 == "member"


# OPERATOR KEANGGOTAAN
daftar_promo_1018 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]

promo_tersedia_1018 = kode_promo_1018 in daftar_promo_1018
promo_tidak_tersedia_1018 = kode_promo_1018 not in daftar_promo_1018


# OPERATOR LOGIKA
diskon_member_1018 = status_anggota_1018 and syarat_belanja_1018

dapat_promo_1018 = (
    syarat_belanja_1018
    and syarat_jumlah_1018
    and promo_tersedia_1018)

akses_pelanggan_1018 = (
    status_anggota_1018
    or promo_tersedia_1018)


# OPERATOR ARITMATIKA
diskon_1018 = 0

if diskon_member_1018:
    diskon_1018 = belanja_1018 * 10 / 100

total_bayar_1018 = belanja_1018 - diskon_1018
rata_rata_1018 = belanja_1018 / jumlah_1018

sisa_bagi_1018 = belanja_1018 % jumlah_1018


# OPERATOR PENUGASAN
total_bayar_1018 += 0
diskon_1018 += 0

poin_1018 = 0
poin_1018 += int(total_bayar_1018 // 10000)


# OPERATOR IDENTITAS
objek_1_1018 = daftar_promo_1018
objek_2_1018 = daftar_promo_1018
objek_3_1018 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]

identitas_sama_1018 = objek_1_1018 is objek_2_1018
identitas_berbeda_1018 = objek_1_1018 is not objek_3_1018
nilai_sama_1018 = objek_1_1018 == objek_3_1018


# OPERATOR BITWISE
status_bit_1018 = 0

if status_anggota_1018:
    status_bit_1018 |= 1       # 0001

if syarat_belanja_1018:
    status_bit_1018 |= 2       # 0010

if syarat_jumlah_1018:
    status_bit_1018 |= 4       # 0100

if promo_tersedia_1018:
    status_bit_1018 |= 8       # 1000

# AND
cek_anggota_1018 = status_bit_1018 & 1
cek_promo_1018 = status_bit_1018 & 8

# OR
kode_gabungan_1018 = 1 | 8

# XOR
kode_referensi_1018 = 11
hasil_xor_1018 = status_bit_1018 ^ kode_referensi_1018

# Pergeseran
hasil_shift_1018 = status_bit_1018 << 1


# HAK AKSES
kode_akses_1018 = 0

if status_anggota_1018:
    kode_akses_1018 |= 1

if promo_tersedia_1018:
    kode_akses_1018 |= 2

if kode_promo_1018 == "GRATISONGKIR":
    kode_akses_1018 |= 4

akses_anggota_1018 = (kode_akses_1018 & 1) != 0
akses_promo_1018 = (kode_akses_1018 & 2) != 0
akses_pengiriman_1018 = (kode_akses_1018 & 4) != 0


# OUTPUT DATA
print("\n==========================================")
print("             DATA TRANSAKSI")
print("==========================================")

print("Nama Pelanggan       :", nama_1018)
print("Status Pelanggan     :", status_1018)
print("Total Belanja        : Rp{:,.0f}".format(belanja_1018))
print("Jumlah Barang        :", jumlah_1018)
print("Kode Promo           :", kode_promo_1018)


# HASIL VALIDASI
print("\n==========================================")
print("             HASIL VALIDASI")
print("==========================================")

print("Belanja >= Rp200000  :", syarat_belanja_1018)
print("Jumlah Barang >= 3   :", syarat_jumlah_1018)
print("Status Anggota       :", status_anggota_1018)
print("Kode Promo Tersedia  :", promo_tersedia_1018)
print("Kode Promo Tidak Ada :", promo_tidak_tersedia_1018)
print("Dapat Diskon Member  :", diskon_member_1018)
print("Dapat Promo           :", dapat_promo_1018)


# HASIL PERHITUNGAN
print("\n==========================================")
print("             HASIL PERHITUNGAN")
print("==========================================")

print("Besarnya Diskon      : Rp{:,.0f}".format(diskon_1018))
print("Total Pembayaran     : Rp{:,.0f}".format(total_bayar_1018))
print("Rata-rata Barang     : Rp{:,.2f}".format(rata_rata_1018))
print("Sisa Pembagian       :", sisa_bagi_1018)
print("Poin Pelanggan       :", poin_1018)


# HAK AKSES PELANGGAN
print("\n==========================================")
print("          HAK AKSES PELANGGAN")
print("==========================================")

print("Kode Hak Akses       :", kode_akses_1018)
print("Akses Anggota        :", akses_anggota_1018)
print("Akses Promo          :", akses_promo_1018)
print("Akses Pengiriman Gratis :", akses_pengiriman_1018)


# OPERATOR IDENTITAS
print("\n==========================================")
print("          OPERATOR IDENTITAS")
print("==========================================")

print("Objek 1 is Objek 2   :", identitas_sama_1018)
print("Objek 1 is not Objek 3 :", identitas_berbeda_1018)
print("Objek 1 == Objek 3   :", nilai_sama_1018)


# OPERASI BITWISE
print("\n==========================================")
print("             OPERASI BITWISE")
print("==========================================")

print("Kode Status Transaksi")
print("Anggota             : 0001")
print("Belanja >= 200000   : 0010")
print("Jumlah >= 3         : 0100")
print("Promo tersedia      : 1000")

print("\nKode Biner           :", format(status_bit_1018, "04b"))
print("Kode Desimal        :", status_bit_1018)

print("\n--- AND ---")
print("Cek Anggota")
print(
    format(status_bit_1018, "04b"),
    "& 0001"
)
print("Hasil Biner         :", format(cek_anggota_1018, "04b"))
print("Hasil Desimal       :", cek_anggota_1018)

print("\nCek Promo")
print(
    format(status_bit_1018, "04b"),
    "& 1000"
)
print("Hasil Biner         :", format(cek_promo_1018, "04b"))
print("Hasil Desimal       :", cek_promo_1018)

print("\n--- OR ---")
print("0001 | 1000")
print("Hasil Biner         :", format(kode_gabungan_1018, "04b"))
print("Hasil Desimal       :", kode_gabungan_1018)

print("\n--- XOR ---")
print("Kode Transaksi      :", format(status_bit_1018, "04b"))
print("Kode Referensi      :", format(kode_referensi_1018, "04b"))
print(
    format(status_bit_1018, "04b"),
    "^",
    format(kode_referensi_1018, "04b")
)
print("Hasil Biner         :", format(hasil_xor_1018, "04b"))
print("Hasil Desimal       :", hasil_xor_1018)

print("\n--- PERGESERAN ---")
print(format(status_bit_1018, "04b"), "<< 1")
print("Hasil Biner         :", format(hasil_shift_1018, "b"))
print("Hasil Desimal       :", hasil_shift_1018)

print("\n==========================================")
print("              SELESAI")
print("==========================================")
# Out:
# ...
#        SISTEM TRANSAKSI TOKO
# ...
#
# ...
#              DATA TRANSAKSI
# ...
# Nama Pelanggan       : syasya
# Status Pelanggan     : member
# Total Belanja        : Rp250,000
# Jumlah Barang        : 5
# Kode Promo           : HEMAT10
#
# ...
#              HASIL VALIDASI
# ...
# Belanja >= Rp200000  : True
# Jumlah Barang >= 3   : True
# Status Anggota       : True
# Kode Promo Tersedia  : True
# Kode Promo Tidak Ada : False
# Dapat Diskon Member  : True
# Dapat Promo           : True
#
# ...
#              HASIL PERHITUNGAN
# ...
# Besarnya Diskon      : Rp25,000
# Total Pembayaran     : Rp225,000
# Rata-rata Barang     : Rp50,000.00
# Sisa Pembagian       : 0.0
# Poin Pelanggan       : 22
#
# ...
#           HAK AKSES PELANGGAN
# ...
# Kode Hak Akses       : 3
# Akses Anggota        : True
# Akses Promo          : True
# Akses Pengiriman Gratis : False
#
# ...
#           OPERATOR IDENTITAS
# ...
# Objek 1 is Objek 2   : True
# Objek 1 is not Objek 3 : True
# Objek 1 == Objek 3   : True
#
# ...
#              OPERASI BITWISE
# ...

# %% [markdown]
# **Penjelasan :**
# 1. Pada program digunakan operator aritmatika untuk menghitung berbagai macam programnya. Oprator perkalian yaitu digunakan untuk menghitung besarnya diskon. Opertaor pembagian digunakan untuk menghitung presentase diskon dan harga rata-rata barang. Operator pengurangan digunakan untuk mendapatkan total pembayaran setelah diskon. Operator modulus digunakan untuk mendapatkan sisa hasil pembagian. Operator pembagian bulat digunakan untuk menentukan jumlah poin pelanggan.
# 2. Operator AND menghasilkan true apabila semua kondisi yang digabungkan bernilai true. Operator OR menghasilkan true apabila minimal salah satu kondisi bernilai true. Sedangkan Operator NOT digunakan untuk membalik nilai boolean.
# 3. Operator in digunakan untuk memeriksa apakah suatu nilai terdapat di dalam sebuah koleksi, dalam program ini terdapat pada list kode promo, sedangkan Operator not in digunakan untuk mengecek promo tidak tersedia.
# 4. is digunakan untuk membandingkan identitas objek, yaitu apakah dua variabel merujuk ke objek yang sama. Sedangkan == digunakan untuk membandingkan nilai atau isi objek.
# 5. Operator bitwise digunakan untuk mengolah kondisi pelanggan dalam bentuk bilangan biner. Program menggunakan empat bit, 0001 dengan nilai 1 = pelanggan anggota, 0010 dengan nilai  = belanja >= Rp200.000, 0100 dengan nilai 4 = jumlah barang >= 3, dan 1000 dengan nilai 8 = kode promo tersedia.
# 6. Alur program dimulai ketika pengguna menjalankan program dan memasukkan data pelanggan. program meminta pengguna untuk menginput nama pelanggan, status pelanggan, total belanja, jumlah barang, dan koe promo. Lalu program memeriksa syarat transaksi yang telah ditentukan dengan membandingkan data. Program memeriksa kode promo yang diinput oleh pengguna, apakah sesuai dengan kode promo yang tersedia. Lalu proghram menentukan diskon dengan operator logika, dalam program jika pelanggan member dan belanja minimal Rp200.000 akan mendapatkan diskon. Menghitung total pembayaran dan menghitung rata-rata barang, serta menentukan status promo. Program akan lanjut dengan mengidentifikasi kondisi yang menghasilkan true dan false.
# 7. kondisi yang menghasilkan true: syarat_belanja_1018 = belanja_1018 >= 200000. Jika total belanja sebesar Rp250.000, maka kondisi 250000 >= 200000 bernilai True, karena total belanja memenuhi batas minimal Rp200.000.
# Kondisi yang menghasilkan False: syarat_jumlah_1018 = jumlah_1018 >= 3. Jika jumlah barang sebanyak 2, maka kondisi 2 >= 3 bernilai False, karena jumlah barang belum memenuhi minimal 3 barang.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa tipe data dan variabel merupakan dasar penting dalam pemrograman Java karena digunakan untuk menyimpan dan mengolah data. Tipe data seperti numerik, String, dan boolean memiliki fungsi yang berbeda sesuai dengan jenis data yang dibutuhkan. Selain itu, konstanta digunakan untuk menyimpan nilai yang tetap dan tidak dapat diubah selama program berjalan. Penggunaan input dengan Scanner juga memungkinkan program menerima data secara langsung dari pengguna. Dengan memahami konsep-konsep tersebut, pembuatan program Java menjadi lebih terstruktur dan sesuai dengan kebutuhan.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, “Built-in Types,” Python 3 Documentation. [Online]. Available: Built-in Types – Python Documentation. [Accessed: Sep. 12, 2026].
#
# [2] Python Software Foundation, “Built-in Functions,” Python 3 Documentation. [Online]. Available: Built-in Functions – Python Documentation. [Accessed: Sep. 12, 2026].
